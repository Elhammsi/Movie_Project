# %% [markdown]
# **import libraries needed in the notebook**

# %%
import pandas as pd 
import requests

# %% [markdown]
# **playing with API, I signup for your TMDB account and get my api key to work with tmdb API.**

# %%
 api_key="api_key=dae3ba89a1da1f18474d5d8b48604ceb"

# %%
 pd.options.display.max_columns = 30

# %% [markdown]
# **Below API url returns details of  movies according to tmdb database.**

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkYWUzYmE4OWExZGExZjE4NDc0ZDVkOGI0ODYwNGNlYiIsInN1YiI6IjY2NTMzYjMzZmU2NzU4NzlmODI1ZWU1NCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.NP1cIiZrUg8SwAZ6Ex01cxMcOUPa2_ktqxuCsOxuUss"
}
#To fetch the details we will use get method of request library and store retrieved information in a response object
response = requests.get(url, headers=headers).json()

#print(response)

# %% [markdown]
# **Now if you observe JSON carefully it has four keys
# page: shows page no. of current page
# results: contains list of dictionary with 20 movies
# total_pages: total pages present on site which contains the detail about movies
# total_results: total popular movies
# We can convert this JSON into pandas dataframe
# Note: we are converting only 'results' dictionary into dataframe as we only need movie details**

# %%
pd.DataFrame(response)
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/fqv8v6AycX...        44414
# 1      1  {'adult': False, 'backdrop_path': '/qrGtVFxaD8...        44414
# 2      1  {'adult': False, 'backdrop_path': '/z121dSTR7P...        44414
# 3      1  {'adult': False, 'backdrop_path': '/H5HjE7Xb9N...        44414
# 4      1  {'adult': False, 'backdrop_path': '/q8IEFmEGGS...        44414
# 5      1  {'adult': False, 'backdrop_path': '/3TNSoa0UHG...        44414
# 6      1  {'adult': False, 'backdrop_path': '/iafs5DG5fG...        44414
# 7      1  {'adult': False, 'backdrop_path': '/xOMo8BRK7P...        44414
# 8      1  {'adult': False, 'backdrop_path': '/1m1rXopfND...        44414
# 9      1  {'adult': False, 'backdrop_path': '/nb3xI8XI3w...        44414
# 10     1  {'adult': False, 'backdrop_path': '/fY3lD0jM5A...        44414
# 11     1  {'adult': False, 'backdrop_path': '/kYgQzzjNis...        44414
# ...

# %%
 pd.DataFrame(response["results"])
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /fqv8v6AycXKsivp1T5yKtLbGXce.jpg            [878, 12, 28]   653346
# 1   False  /qrGtVFxaD8c7et0jUtaYhyTzzPg.jpg            [878, 28, 12]   823464
# 2   False  /z121dSTR7PY9KxKuvwiIFSYW8cf.jpg          [10752, 28, 18]   929590
# 3   False   /H5HjE7Xb9N09rbWn1zBfxgI8uz.jpg                 [28, 35]   746036
# 4   False  /q8IEFmEGGSGmAWfwRs23XDwdFN4.jpg            [28, 12, 878]   786892
# 5   False  /3TNSoa0UHGEzEz5ndXGjJVKo8RJ.jpg                [878, 28]   614933
# 6   False  /iafs5DG5fGq7ef0acl3xlX4BFrs.jpg              [18, 10770]  1219685
# 7   False  /xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg                [878, 12]   693134
# 8   False  /1m1rXopfNDVL3UMiv6kriYaJ3yE.jpg        [28, 53, 80, 878]   882059
# 9   False  /nb3xI8XI3w4pMVZ38VijbsyBqP4.jpg                 [18, 36]   872585
# 10  False  /fY3lD0jM5AoHJMunjGWqJ0hRteI.jpg            [878, 27, 28]   940721
# ...

# %% [markdown]
# **iterating through  pages to get all information**

# %%
df = pd.DataFrame()
for i in range(1,2000):
    url = "https://api.themoviedb.org/3/discover/movie"
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkYWUzYmE4OWExZGExZjE4NDc0ZDVkOGI0ODYwNGNlYiIsInN1YiI6IjY2NTMzYjMzZmU2NzU4NzlmODI1ZWU1NCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.NP1cIiZrUg8SwAZ6Ex01cxMcOUPa2_ktqxuCsOxuUss"
}

    response = requests.get(url, headers=headers).json()
    temporary_df= pd.DataFrame(response["results"])
    df = pd.concat([df,temporary_df],ignore_index=True)

# %%
 df.info()

# %% [markdown]
# **Extracting id to get other information about movies**

# %%
 movie_id =df['id']

# %%
 basic_url = 'https://api.themoviedb.org/3/movie/{}?{}'

# %%
 json_list = []
for movie in movie_id:
    url = basic_url.format(movie, api_key)
    r = requests.get(url)
    if r.status_code != 200:
        continue
    else:
        data = r.json()
        json_list.append(data) 
df2 = pd.DataFrame(json_list)

# %%
 df2.to_csv("movies_raw.csv", index = False)

# %%
df = pd.read_csv("movies_raw.csv")
# Out:
# C:\Users\elham\AppData\Local\Temp\ipykernel_17600\440248667.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("movies_raw.csv")

# %%
 df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# # ** Dropping irrelevant Columns**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.drop(columns = ['adult'], inplace = True)

# %%
df.drop(columns = ['imdb_id'], inplace = True)

# %%
df.drop(columns = ['original_title'], inplace = True)

# %%
df.drop(columns = ['video'], inplace= True)

# %%
df.drop(columns = ['homepage'], inplace= True)

# %% [markdown]
# **Handeling stringified JSON columns
# The application of this transformation is necessary when we have a column in  DataFrame that contains strings representing JSON objects or Python dictionaries, and we want to convert these strings into actual Python objects (dictionaries in this case) for easier manipulation and analysis.**

# %%
import json
import ast
import numpy as np

# %%
json_col = ["belongs_to_collection", "genres", "production_countries", 
            "production_companies", "spoken_languages"]

# %%
df[json_col].head()
# Out:
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                 production_countries  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...
# ...

# %% [markdown]
# The isinstance() function returns True if the specified object is of the specified type, otherwise False.

# %%
df.belongs_to_collection.apply(lambda x: isinstance(x, str))
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45466, dtype: bool

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.belongs_to_collection [0]
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
df.spoken_languages[0]
# Out:
# "[{'iso_639_1': 'en', 'name': 'English'}]"

# %%
df.spoken_languages = df.spoken_languages.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.spoken_languages.replace("", np.nan, inplace = True)

# %%
df.production_countries
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_countries = df.production_countries.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.production_companies
# Out:
# 0           [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1        [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3        [{'name': 'Twentieth Century Fox Film Corporat...
# 4        [{'name': 'Sandollar Productions', 'id': 5842}...
#                                ...
# 45461                                                   []
# 45462               [{'name': 'Sine Olivia', 'id': 19653}]
# 45463    [{'name': 'American World Pictures', 'id': 6165}]
# 45464                 [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                   []
# Name: production_companies, Length: 45466, dtype: object

# %%
df.production_companies = df.production_companies.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.production_countries.replace("", np.nan, inplace = True)

# %%
df.production_companies.replace("", np.nan, inplace = True)

# %%
df.genres = df.genres.apply(ast.literal_eval)

# %%
df.genres.replace("", np.nan, inplace = True)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# ...

# %% [markdown]
# # flatten nested Columns

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %% [markdown]
# We have nested dictionary but we are interested in the name so we applay lambda only on the name and check if it is dictionary or not

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x: x['name'] if isinstance(x, dict) else np.nan)

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 45461                               NaN
# 45462                               NaN
# 45463                               NaN
# 45464                               NaN
# 45465                               NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection.value_counts(dropna = False).head(20)
# Out:
# belongs_to_collection
# NaN                                       40975
# The Bowery Boys                              29
# Totò Collection                              27
# James Bond Collection                        26
# Zatôichi: The Blind Swordsman                26
# The Carry On Collection                      25
# Pokémon Collection                           22
# Charlie Chan (Sidney Toler) Collection       21
# Godzilla (Showa) Collection                  16
# Uuno Turhapuro                               15
# Dragon Ball Z (Movie) Collection             15
# Charlie Chan (Warner Oland) Collection       15
# The Land Before Time Collection              14
# Monster High Collection                      14
# Sharpe Collection                            13
# George Carlin Comedy Collection              13
# Johan Falk GSI Collection                    12
# Sherlock Holmes (1939 series)                12
# Friday the 13th Collection                   12
# ...

# %% [markdown]
# **In genres column we have list with dictionary. In genre column also we have interested in name but we have 3 names so we seperate them with |.**

# %%
df.genres[1]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df.genres = df.genres.apply(lambda x: "|".join(i['name'] for i in x))

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
df.genres.value_counts(dropna = False).head(20)
# Out:
# genres
# Drama                   5000
# Comedy                  3621
# Documentary             2723
#                         2442
# Drama|Romance           1301
# Comedy|Drama            1135
# Horror                   974
# Comedy|Romance           930
# Comedy|Drama|Romance     593
# Drama|Comedy             532
# Horror|Thriller          528
# Drama|Thriller           497
# Thriller                 465
# Crime|Drama              430
# Romance|Drama            343
# Western                  318
# Action|Thriller          301
# Drama|Foreign            283
# Action                   278
# Drama|History            267
# Name: count, dtype: int64

# %%
df.genres.replace("", np.nan, inplace = True)

# %%
df.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %% [markdown]
# **we are interested in name of language so..**

# %%
df.spoken_languages = df.spoken_languages.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.spoken_languages.value_counts(dropna = False).head(20)
# Out:
# spoken_languages
# English             22395
#                      3952
# Français             1853
# 日本語                  1289
# Italiano             1218
# Español               902
# Pусский               807
# Deutsch               762
# English|Français      681
# English|Español       572
# हिन्दी                481
# English|Deutsch       462
# 한국어/조선말               425
# 普通话                   347
# English|Italiano      326
# svenska               311
# No Language           303
# suomi                 275
# Português             275
# Polski                213
# Name: count, dtype: int64

# %%
df.spoken_languages.replace("", np.nan, inplace = True)

# %%
df.production_countries
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_countries = df.production_countries.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.production_countries.value_counts(dropna = False).head(20)
# Out:
# production_countries
# United States of America                   17851
#                                             6282
# United Kingdom                              2238
# France                                      1654
# Japan                                       1356
# Italy                                       1030
# Canada                                       840
# Germany                                      749
# India                                        735
# Russia                                       735
# United Kingdom|United States of America      569
# South Korea                                  432
# Spain                                        398
# Hong Kong                                    365
# Canada|United States of America              365
# Australia                                    336
# Sweden                                       332
# Finland                                      271
# France|Italy                                 235
# ...

# %%
#in case we have empty value
df.production_countries.replace("", np.nan, inplace = True)

# %%
df.production_companies[0]
# Out:
# [{'name': 'Pixar Animation Studios', 'id': 3}]

# %%
df.production_companies = df.production_companies.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.production_companies.value_counts(dropna = False).head(20)
# Out:
# production_companies
#                                           11875
# Metro-Goldwyn-Mayer (MGM)                   742
# Warner Bros.                                540
# Paramount Pictures                          505
# Twentieth Century Fox Film Corporation      439
# Universal Pictures                          320
# RKO Radio Pictures                          247
# Columbia Pictures Corporation               207
# Columbia Pictures                           146
# Mosfilm                                     145
# Walt Disney Pictures                         85
# Universal International Pictures (UI)        82
# New Line Cinema                              75
# Walt Disney Productions                      75
# Shaw Brothers                                71
# Touchstone Pictures                          70
# Toho Company                                 65
# TriStar Pictures                             62
# Orion Pictures                               61
# ...

# %%
df.production_companies.replace("", np.nan, inplace = True)

# %%
df.isna().sum()# checking all missing values
# Out:
# belongs_to_collection    40975
# budget                       0
# genres                    2442
# id                           0
# original_language           11
# overview                   954
# popularity                   5
# poster_path                386
# production_companies     11881
# production_countries      6288
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages          3958
# status                      87
# tagline                  25054
# title                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
pd.read_csv("movies_raw.csv", low_memory=False).isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
#
# # **Cleaning Numerical Columns*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
df.budget.value_counts(dropna = False)
# Out:
# budget
# 0           36573
# 5000000       286
# 10000000      259
# 20000000      243
# 2000000       242
#             ...
# 923             1
# 72500000        1
# 2160000         1
# 4439832         1
# 1254040         1
# Name: count, Length: 1226, dtype: int64

# %% [markdown]
# **here we can see that budget 0 is the most frequent value which is unrealistic. It mighte be a placeholder for missing value**

# %%
df.budget = df.budget.replace(0, np.nan)

# %%
df.budget = pd.to_numeric(df.budget, errors = "coerce")

# %% [markdown]
# For more readability of budget we divide budget 1000000

# %%
df.budget = df.budget.div(1000000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45463 non-null  float64
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
df.revenue.value_counts(dropna = False)
# Out:
# revenue
# 0.0           38052
# 12000000.0       20
# 10000000.0       19
# 11000000.0       19
# 2000000.0        18
#               ...
# 36565280.0        1
# 439564.0          1
# 35610100.0        1
# 10217873.0        1
# 1413000.0         1
# Name: count, Length: 6864, dtype: int64

# %% [markdown]
# **we have the same problem with revenue column**

# %%
df.revenue = df.revenue.replace(0, np.nan)
df.revenue = df.revenue.div(1000000)

# %%
df.rename(columns = {"revenue":"revenue_musd", "budget":"budget_musd"}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            45463 non-null  float64
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
df.runtime.value_counts(dropna = False).head(20)
# Out:
# runtime
# 90.0     2556
# 0.0      1558
# 100.0    1470
# 95.0     1412
# 93.0     1214
# 96.0     1104
# 92.0     1080
# 94.0     1062
# 91.0     1057
# 88.0     1032
# 97.0     1027
# 85.0     1024
# 98.0     1019
# 105.0    1002
# 89.0      958
# 87.0      919
# 110.0     850
# 86.0      846
# 99.0      794
# 102.0     791
# Name: count, dtype: int64

# %%
df.runtime = df.runtime.replace(0, np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            45463 non-null  float64
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
df.id.value_counts(dropna = False).head(20)
# Out:
# id
# 141971    3
# 168538    2
# 25541     2
# 15028     2
# 11115     2
# 84198     2
# 13209     2
# 77221     2
# 152795    2
# 12600     2
# 10991     2
# 42495     2
# 14788     2
# 18440     2
# 105045    2
# 159849    2
# 22649     2
# 4912      2
# 132641    2
# 110428    2
# Name: count, dtype: int64

# %% [markdown]
# **here we can see that we have some duplicate value. the id should be unique**

# %%
df.popularity.value_counts(dropna = False).head(20)
# Out:
# popularity
# 0.0         34
# 0.0         32
# 1e-06       30
# 1e-06       26
# 0.000844    26
# 0.000578    25
# 0.00022     24
# 0.000308    23
# 0.001177    22
# 0.000308    20
# 0.002001    19
# 0.00022     16
# 0.003013    16
# 0.001177    16
# 0.036471    14
# 0.000578    13
# 0.002353    13
# 0.00353     12
# 0.000844    12
# 0.001393    11
# Name: count, dtype: int64

# %%
df.vote_count.value_counts(dropna = False).head(20)
# Out:
# vote_count
# 1.0     3264
# 2.0     3132
# 0.0     2899
# 3.0     2787
# 4.0     2480
# 5.0     2097
# 6.0     1747
# 7.0     1570
# 8.0     1359
# 9.0     1194
# 10.0    1171
# 11.0     944
# 12.0     859
# 13.0     733
# 14.0     700
# 15.0     674
# 16.0     601
# 17.0     554
# 18.0     497
# 20.0     463
# Name: count, dtype: int64

# %%
df.vote_average.value_counts(dropna = False).head(20)# the average rating
# Out:
# vote_average
# 0.0    2998
# 6.0    2468
# 5.0    2001
# 7.0    1886
# 6.5    1722
# 6.3    1603
# 5.5    1381
# 5.8    1369
# 6.4    1350
# 6.7    1342
# 6.8    1324
# 6.1    1281
# 6.6    1263
# 6.2    1253
# 5.9    1196
# 5.3    1082
# 5.7    1046
# 6.9    1037
# 5.6    1006
# 7.3    1000
# Name: count, dtype: int64

# %% [markdown]
# **the average rating of 0 does not make sense. for these movies we have the rate of 0**

# %%
df.loc[df.vote_count == 0, "vote_average"]
# Out:
# 83       0.0
# 107      0.0
# 126      0.0
# 132      0.0
# 137      0.0
#         ...
# 45432    0.0
# 45434    0.0
# 45452    0.0
# 45464    0.0
# 45465    0.0
# Name: vote_average, Length: 2899, dtype: float64

# %% [markdown]
# **so we change them to missing values**

# %%
df.loc[df.vote_count == 0, "vote_average"] = np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            45463 non-null  float64
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %% [markdown]
# **so far we have right and appropriate type for numerical column**

# %% [markdown]
# # *Cleaning DateTime Columns*

# %% [markdown]
# **release_date should be date type not bject so...**

# %%
df.release_date
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45461           NaN
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45466, dtype: object

# %%
df.release_date = pd.to_datetime(df.release_date, errors = "coerce")

# %%
df.release_date.value_counts(dropna = False).head(20)
# Out:
# release_date
# 2008-01-01    136
# 2009-01-01    121
# 2007-01-01    118
# 2005-01-01    111
# 2006-01-01    101
# 2002-01-01     96
# 2004-01-01     90
# NaT            90
# 2001-01-01     84
# 2003-01-01     76
# 1997-01-01     69
# 2010-01-01     68
# 1998-01-01     67
# 1999-01-01     67
# 2000-01-01     64
# 1987-01-01     63
# 1988-01-01     63
# 1994-01-01     61
# 1989-01-01     60
# 2011-01-01     56
# Name: count, dtype: int64

# %% [markdown]
# # **Cleaning Text / String Columns**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            45463 non-null  float64
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45376 non-null  datetime64[ns]
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %%
df.original_language.value_counts(dropna = False).head(50)#discovering 50 most frequent languages
# Out:
# original_language
# en     32269
# fr      2438
# it      1529
# ja      1350
# de      1080
# es       994
# ru       826
# hi       508
# ko       444
# zh       409
# sv       384
# pt       316
# cn       313
# fi       297
# nl       248
# da       225
# pl       219
# tr       150
# cs       130
# el       113
# no       106
# fa       101
# hu       100
# ta        78
# th        76
# he        67
# sr        63
# ro        57
# te        45
# ar        39
# ml        36
# xx        33
# bn        29
# hr        29
# mr        25
# is        24
# et        24
# tl        23
# id        20
# lv        18
# ka        18
# sl        17
# uk        16
# bs        14
# ca        12
# NaN       11
# bg        10
# ab        10
# vi        10
# sk         9
# Name: count, dtype: int64

# %%
df.title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45461                         Subdue
# 45462            Century of Birthing
# 45463                       Betrayal
# 45464               Satan Triumphant
# 45465                       Queerama
# Name: title, Length: 45466, dtype: object

# %%
df.title.value_counts(dropna = False).head(20)
# Out:
# title
# Cinderella              11
# Alice in Wonderland      9
# Hamlet                   9
# Les Misérables           8
# Beauty and the Beast     8
# Treasure Island          7
# A Christmas Carol        7
# The Three Musketeers     7
# Blackout                 7
# Home                     6
# Macbeth                  6
# The Journey              6
# The Hunters              6
# The Forest               6
# Mother                   6
# Countdown                6
# Love                     6
# The Stranger             6
# Heidi                    6
# Bluebeard                6
# Name: count, dtype: int64

# %%
df.overview[0] # this is short summery for movie
# Out:
# "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences."

# %%
df.overview.value_counts(dropna = False).head(10)
# Out:
# overview
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               954
# ...

# %% [markdown]
# **here we can see that we have some missing values. some of them is nan some white space ,...**

# %%
df.overview.replace("No overview found.", np.nan, inplace = True)

# %%
df.overview.replace("No Overview", np.nan, inplace = True)

# %%
df.overview.replace("No movie overview available.", np.nan, inplace = True)

# %%
df.overview.replace(" ", np.nan, inplace = True)# this is for white space

# %%
df.overview.replace("No overview yet.", np.nan, inplace = True)

# %%
df.tagline.value_counts(dropna = False).head(50)
# Out:
# tagline
# NaN                                                                                                                      25054
# Based on a true story.                                                                                                       7
# Trust no one.                                                                                                                4
# Be careful what you wish for.                                                                                                4
# -                                                                                                                            4
# Classic Albums                                                                                                               3
# Some doors should never be opened.                                                                                           3
# ...

# %% [markdown]
# **here also we have missing values and some of the have - value**

# %%
df.tagline.replace("-", np.nan, inplace = True)

# %% [markdown]
# # **Removing Duplicates**

# %% [markdown]
# **we find and display duplicated rows in a DataFrame and then sort these rows by a specific column, id.The parameter keep=False means that all instances of a duplicated row are marked as duplicates (not just the second and subsequent occurrences).**

# %%
df[df.duplicated(keep =  False)].sort_values(by = "id")
# Out:
#       belongs_to_collection  budget_musd  \
# 676                     NaN         0.00
# 1465                    NaN         0.00
# 24844                   NaN         0.00
# 14012                   NaN         0.00
# 21165                   NaN         0.00
# 19890                   NaN         0.00
# 13375                   NaN         0.00
# 16764                   NaN         0.00
# 13261                   NaN         0.00
# 21854                   NaN         0.00
# 19925                   NaN         0.00
# 13603                   NaN         0.00
# 28860                   NaN         0.00
# 14000                   NaN         0.00
# 22151                   NaN         0.00
# 8068                    NaN         0.00
# 9327                    NaN         0.00
# 17229                   NaN         0.00
# 23044                   NaN         0.00
# 33184                   NaN         0.98
# 40040                   NaN         0.98
# 15702                   NaN         0.00
# ...

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# **we find rows in a DataFrame where the id column has duplicate values, and then sort these duplicated rows by the id column.**

# %%
df[df.duplicated(subset = "id", keep = False)].sort_values(by = "id")
# Out:
#       belongs_to_collection  budget_musd  \
# 44821    Pokémon Collection    16.000000
# 4114     Pokémon Collection    16.000000
# 20899                   NaN     0.000000
# 5710                    NaN     0.000000
# 4356                    NaN     3.512454
# 23534                   NaN     3.512454
# 5535     Pokémon Collection     0.000000
# 44826    Pokémon Collection     0.000000
# 15765                   NaN     0.002500
# 11342                   NaN     0.002500
# 838                     NaN     0.000000
# 30001                   NaN     0.000000
# 12066                   NaN     1.600000
# 10419                   NaN     1.600000
# 5130                    NaN    26.000000
# 33743                   NaN    26.000000
# 13220          Why We Fight     0.000000
# 35798          Why We Fight     0.000000
# 15074                   NaN     0.000004
# 949                     NaN     0.000004
# 24164                   NaN     0.000000
# 45265                   NaN     0.000000
# ...

# %%
df.drop_duplicates(subset = "id", inplace = True)

# %%
df.id.value_counts(dropna = False)
# Out:
# id
# 862       1
# 40777     1
# 107308    1
# 16247     1
# 99904     1
#          ..
# 44399     1
# 10138     1
# 32084     1
# 42191     1
# 461257    1
# Name: count, Length: 45436, dtype: int64

# %% [markdown]
# **finally we deleted all dupplicate**

# %% [markdown]
# # **Handling Missing Values & Removing Observations**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4488 non-null   object
#  1   budget_musd            45433 non-null  float64
#  2   genres                 42994 non-null  object
#  3   id                     45436 non-null  object
#  4   original_language      45425 non-null  object
#  5   overview               44332 non-null  object
#  6   popularity             45431 non-null  object
#  7   poster_path            45050 non-null  object
#  8   production_companies   33562 non-null  object
#  9   production_countries   39151 non-null  object
#  10  release_date           45346 non-null  datetime64[ns]
#  11  revenue_musd           7398 non-null   float64
#  12  runtime                43615 non-null  float64
#  13  spoken_languages       41480 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40948
# budget_musd                  3
# genres                    2442
# id                           0
# original_language           11
# overview                  1104
# popularity                   5
# poster_path                386
# production_companies     11874
# production_countries      6285
# release_date                90
# revenue_musd             38038
# runtime                   1821
# spoken_languages          3956
# status                      87
# tagline                  25039
# title                        6
# vote_average              2902
# vote_count                   6
# dtype: int64

# %%
df[df.title.isna()]# the movies with missing value. they have many missing values and we donot have much 
# information about these movies
# Out:
#              belongs_to_collection  budget_musd  \
# 19729                          NaN          0.0
# 19730                          NaN          NaN
# 29502  Mardock Scramble Collection          0.0
# 29503                          NaN          NaN
# 35586                          NaN          0.0
# 35587                          NaN          NaN
#
#                                                   genres          id  \
# 19729                              Action|Thriller|Drama       82663
# 19730  Carousel Productions|Vision View Entertainment...  1997-08-20
# 29502                          Animation|Science Fiction      122662
# 29503  Aniplex|GoHands|BROSTA TV|Mardock Scramble Pro...  2012-09-29
# 35586             TV Movie|Action|Horror|Science Fiction      249260
# 35587  Odyssey Media|Pulser Productions|Rogue State|T...  2014-01-01
#
#       original_language                                           overview  \
# ...

# %%
df.dropna(subset = ["title"], inplace = True)

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40943
# budget_musd                  0
# genres                    2442
# id                           0
# original_language           11
# overview                  1104
# popularity                   0
# poster_path                383
# production_companies     11868
# production_countries      6279
# release_date                84
# revenue_musd             38032
# runtime                   1815
# spoken_languages          3950
# status                      81
# tagline                  25033
# title                        0
# vote_average              2896
# vote_count                   0
# dtype: int64

# %%
df.id = df.id.astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45430 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4487 non-null   object
#  1   budget_musd            45430 non-null  float64
#  2   genres                 42988 non-null  object
#  3   id                     45430 non-null  int32
#  4   original_language      45419 non-null  object
#  5   overview               44326 non-null  object
#  6   popularity             45430 non-null  object
#  7   poster_path            45047 non-null  object
#  8   production_companies   33562 non-null  object
#  9   production_countries   39151 non-null  object
#  10  release_date           45346 non-null  datetime64[ns]
#  11  revenue_musd           7398 non-null   float64
#  12  runtime                43615 non-null  float64
#  13  spoken_languages       41480 non-null  object
# ...

# %% [markdown]
# **This tells us how many rows have a certain number of non-missing values, helping you understand the data's completeness distribution.If we want to understand the completeness of  dataset. For instance, if many rows have fewer non-missing values, we might need to handle missing data before performing further analysis.For example we have 4 movies that have 7 non missing valuses**

# %%
df.notna().sum(axis = 1).value_counts().sort_values(ascending = False)
# Out:
# 16    13375
# 17    12540
# 15     5672
# 18     5671
# 14     3075
# 13     1935
# 19     1295
# 12     1038
# 11      513
# 10      186
# 9       106
# 8        20
# 7         4
# Name: count, dtype: int64

# %%
df[df.notna().sum(axis = 1) ==7 ]
# Out:
#       belongs_to_collection  budget_musd genres      id original_language  \
# 18038                   NaN          0.0    NaN  344741                pl
# 20166                   NaN          0.0    NaN  139909                fi
# 41718                   NaN          0.0    NaN  216550                de
# 44978                   NaN          0.0    NaN  398295                pt
#
#       overview popularity poster_path production_companies  \
# 18038      NaN        0.0         NaN                  NaN
# 20166      NaN   0.000127         NaN                  NaN
# 41718      NaN        0.0         NaN                  NaN
# 44978      NaN   0.000331         NaN                  NaN
#
#       production_countries release_date  revenue_musd  runtime  \
# 18038                  NaN          NaT           NaN      NaN
# 20166                  NaN          NaT           NaN      NaN
# 41718                  NaN          NaT           NaN      NaN
# ...

# %%
df.dropna(thresh = 10, inplace = True)# we remove rows with more than 10 missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45300 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4487 non-null   object
#  1   budget_musd            45300 non-null  float64
#  2   genres                 42983 non-null  object
#  3   id                     45300 non-null  int32
#  4   original_language      45289 non-null  object
#  5   overview               44251 non-null  object
#  6   popularity             45300 non-null  object
#  7   poster_path            45007 non-null  object
#  8   production_companies   33562 non-null  object
#  9   production_countries   39151 non-null  object
#  10  release_date           45249 non-null  datetime64[ns]
#  11  revenue_musd           7398 non-null   float64
#  12  runtime                43605 non-null  float64
#  13  spoken_languages       41476 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40813
# budget_musd                  0
# genres                    2317
# id                           0
# original_language           11
# overview                  1049
# popularity                   0
# poster_path                293
# production_companies     11738
# production_countries      6149
# release_date                51
# revenue_musd             37902
# runtime                   1695
# spoken_languages          3824
# status                      72
# tagline                  24903
# title                        0
# vote_average              2776
# vote_count                   0
# dtype: int64

# %%
df.status.value_counts()
# Out:
# status
# Released           44866
# Rumored              227
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: count, dtype: int64

# %% [markdown]
# **we are interested in released movies so..**

# %%
df = df.loc[df.status == "Released"].copy()

# %%
df.drop(columns = ["status"], inplace = True)

# %%
df.head(2)
# Out:
#   belongs_to_collection  budget_musd                    genres    id  \
# 0  Toy Story Collection         30.0   Animation|Comedy|Family   862
# 1                   NaN         65.0  Adventure|Fantasy|Family  8844
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries release_date  revenue_musd  runtime  \
# 0  United States of America   1995-10-30    373.554033     81.0
# 1  United States of America   1995-12-15    262.797249    104.0
#
# ...

# %% [markdown]
# **we can also order the column based on their importans**

# %%
col = ["id", "title", "tagline", "release_date", "genres", "belongs_to_collection", 
       "original_language", "budget_musd", "revenue_musd", "production_companies",
       "production_countries", "vote_count", "vote_average", "popularity", "runtime",
       "overview", "spoken_languages", "poster_path"]
df = df.loc[:, col]

# %%
df.head(2)
# Out:
#      id      title                                    tagline release_date  \
# 0   862  Toy Story                                        NaN   1995-10-30
# 1  8844    Jumanji  Roll the dice and unleash the excitement!   1995-12-15
#
#                      genres belongs_to_collection original_language  \
# 0   Animation|Comedy|Family  Toy Story Collection                en
# 1  Adventure|Fantasy|Family                   NaN                en
#
#    budget_musd  revenue_musd  \
# 0         30.0    373.554033
# 1         65.0    262.797249
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries  vote_count  vote_average popularity  runtime  \
# 0  United States of America      5415.0           7.7  21.946943     81.0
# 1  United States of America      2413.0           6.9  17.015539    104.0
#
# ...

# %% [markdown]
# **we droped many rows so we should start the index**

# %%
df.reset_index(drop = True, inplace =True)

# %% [markdown]
# **we can change the path to html tag**

# %%
df.poster_path[0]
# Out:
# '/rhIRbceoE9lR4veEXuwCC2wARtG.jpg'

# %%
base_poster_url = 'http://image.tmdb.org/t/p/w185/'
df.poster_path = "<img src='" + base_poster_url + df.poster_path + "' style='height:100px;'>"

# %%
df.poster_path[0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//rhIRbceoE9lR4veEXuwCC2wARtG.jpg' style='height:100px;'>"

# %%
df.to_csv("movies_clean.csv", index = False)

# %% [markdown]
# # *Importing clean dataset*

# %%
df=pd.read_csv("movies_clean.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44866 entries, 0 to 44865
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44866 non-null  int64
#  1   title                  44866 non-null  object
#  2   tagline                20285 non-null  object
#  3   release_date           44821 non-null  object
#  4   genres                 42599 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44856 non-null  object
#  7   budget_musd            44866 non-null  float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33357 non-null  object
#  10  production_countries   38839 non-null  object
#  11  vote_count             44866 non-null  float64
#  12  vote_average           42138 non-null  float64
#  13  popularity             44866 non-null  float64
# ...

# %% [markdown]
# **we have another dataset 'credits.csv', that contains some information about crew and cast with the id of the film so we can merging these 2 dataset**

# %%
credits = pd.read_csv("credits.csv")

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %% [markdown]
# **here we have some stringified json data**

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
credits.cast[0]
# Out:
# "[{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH
# ...

# %%
credits.crew[0]
# Out:
# '[{\'credit_id\': \'52fe4284c3a36847f8024f49\', \'department\': \'Directing\', \'gender\': 2, \'id\': 7879, \'job\': \'Director\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f4f\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12891, \'job\': \'Screenplay\', \'name\': \'Joss Whedon\', \'profile_path\': \'/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f55\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7, \'job\': \'Screenplay\', \'name\': \'Andrew Stanton\', \'profile_path\': \'/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f5b\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12892, \'job\': \'Screenplay\', \'name\': \'Joel Cohen\', \'profile_path\': \'/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f61\', \'department\': \'Writing\', \'gender\': 0, \'id\': 12893, \'job\': \'Screenplay\', \'name\': \
# ...

# %% [markdown]
# # *Preparing the Data for Merge*

# %% [markdown]
# **we have to check the id because it is important for meging.As can be seen it has some duplicate id.thus we have to identfiy and remove them**

# %%
credits.id.value_counts()
# Out:
# id
# 141971    3
# 298721    2
# 9755      2
# 10991     2
# 99080     2
#          ..
# 55135     1
# 15877     1
# 72272     1
# 1549      1
# 461257    1
# Name: count, Length: 45432, dtype: int64

# %%
credits[credits.duplicated(subset = ["id"], keep = False)].sort_values("id")
# Out:
#                                                     cast  \
# 25885  [{'cast_id': 12, 'character': 'The Creature', ...
# 25950  [{'cast_id': 12, 'character': 'The Creature', ...
# 33838  [{'cast_id': 15, 'character': 'Chuck Barris', ...
# 5865   [{'cast_id': 15, 'character': 'Chuck Barris', ...
# 9165   [{'cast_id': 11, 'character': 'Jef Costello', ...
# ...                                                  ...
# 25887  [{'cast_id': 7, 'character': 'Hollander', 'cre...
# 24163  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 45275  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 33196  [{'cast_id': 1, 'character': 'Jenjira', 'credi...
# 40051  [{'cast_id': 1, 'character': 'Jenjira', 'credi...
#
#                                                     crew      id
# 25885  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...    3057
# 25950  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...    3057
# 33838  [{'credit_id': '52fe43e2c3a36847f80760a9', 'de...    4912
# ...

# %%
credits.drop_duplicates(subset = "id", inplace = True)

# %%
credits.id.value_counts()#check again for duplicate
# Out:
# id
# 862       1
# 74458     1
# 296206    1
# 107308    1
# 16247     1
#          ..
# 32985     1
# 44399     1
# 10138     1
# 32084     1
# 461257    1
# Name: count, Length: 45432, dtype: int64

# %% [markdown]
# ## Merging the Data (Left Join)

# %% [markdown]
# **first of all, we can check whether there are any movies in df for which we do not have a cast
# and crew information .So we check for all movies, whether they are not in the credits.The output means that we can get all cast for all movies**

# %%
df[~df.id.isin(credits.id)]
# Out:
#            id         title tagline release_date genres belongs_to_collection  \
# 42355  401840  School's out     NaN   2017-05-30    NaN                   NaN
#
#       original_language  budget_musd  revenue_musd production_companies  \
# 42355                es          0.0           NaN                  NaN
#
#       production_countries  vote_count  vote_average  popularity  runtime  \
# 42355                  NaN         0.0           NaN    0.207775      NaN
#
#                                                 overview spoken_languages  \
# 42355  Two high school kids mentored by a nightclub o...              NaN
#
#                                              poster_path
# 42355  <img src='http://image.tmdb.org/t/p/w185//4JI7...

# %%
credits[~credits.id.isin(df.id)]
# Out:
#                                                     cast  \
# 189    [{'cast_id': 4, 'character': 'Himself', 'credi...
# 682    [{'cast_id': 2, 'character': 'Eunice', 'credit...
# 711                                                   []
# 734    [{'cast_id': 3, 'character': 'George', 'credit...
# 767                                                   []
# ...                                                  ...
# 45217  [{'cast_id': 4, 'character': 'Jin', 'credit_id...
# 45299  [{'cast_id': 0, 'character': 'Önni', 'credit_i...
# 45320  [{'cast_id': 0, 'character': 'Mała metalowa dz...
# 45348                                                 []
# 45452                                                 []
#
#                                                     crew      id
# 189                                                   []   56088
# 682    [{'credit_id': '52fe475cc3a36847f81317f7', 'de...   48260
# 711                                                   []  365371
# ...

# %% [markdown]
# **567 movies id are in credits but not in df. they are possibly those movies that we droped in df dataset. then we performe left join**

# %%
df = df.merge(credits, how = "left", left_on = "id", right_on = "id")

# %%
df.head(2)
# Out:
#      id      title                                    tagline release_date  \
# 0   862  Toy Story                                        NaN   1995-10-30
# 1  8844    Jumanji  Roll the dice and unleash the excitement!   1995-12-15
#
#                      genres belongs_to_collection original_language  \
# 0   Animation|Comedy|Family  Toy Story Collection                en
# 1  Adventure|Fantasy|Family                   NaN                en
#
#    budget_musd  revenue_musd  \
# 0         30.0    373.554033
# 1         65.0    262.797249
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 0  United States of America      5415.0           7.7   21.946943     81.0
# 1  United States of America      2413.0           6.9   17.015539    104.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44866 entries, 0 to 44865
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44866 non-null  int64
#  1   title                  44866 non-null  object
#  2   tagline                20285 non-null  object
#  3   release_date           44821 non-null  object
#  4   genres                 42599 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44856 non-null  object
#  7   budget_musd            44866 non-null  float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33357 non-null  object
#  10  production_countries   38839 non-null  object
#  11  vote_count             44866 non-null  float64
#  12  vote_average           42138 non-null  float64
#  13  popularity             44866 non-null  float64
# ...

# %% [markdown]
# ## Cleaning and Transforming the new "Cast" Column

# %%
df.cast[0]
# Out:
# "[{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH
# ...

# %%
df.cast = df.cast.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
pd.DataFrame(df.cast[0])
# Out:
#     cast_id                character                 credit_id  gender  \
# 0        14            Woody (voice)  52fe4284c3a36847f8024f95       2
# 1        15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2
# 2        16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2
# 3        17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2
# 4        18              Rex (voice)  52fe4284c3a36847f8024fa5       2
# 5        19             Hamm (voice)  52fe4284c3a36847f8024fa9       2
# 6        20          Bo Peep (voice)  52fe4284c3a36847f8024fad       1
# 7        26             Andy (voice)  52fe4284c3a36847f8024fc1       0
# 8        22              Sid (voice)  52fe4284c3a36847f8024fb1       2
# 9        23       Mrs. Davis (voice)  52fe4284c3a36847f8024fb5       1
# 10       24         Sergeant (voice)  52fe4284c3a36847f8024fb9       2
# 11       25           Hannah (voice)  52fe4284c3a36847f8024fbd       1
# ...

# %%
df.cast[0]
# Out:
# [{'cast_id': 14,
#   'character': 'Woody (voice)',
#   'credit_id': '52fe4284c3a36847f8024f95',
#   'gender': 2,
#   'id': 31,
#   'name': 'Tom Hanks',
#   'order': 0,
#   'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'},
#  {'cast_id': 15,
#   'character': 'Buzz Lightyear (voice)',
#   'credit_id': '52fe4284c3a36847f8024f99',
#   'gender': 2,
#   'id': 12898,
#   'name': 'Tim Allen',
#   'order': 1,
#   'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'},
#  {'cast_id': 16,
#   'character': 'Mr. Potato Head (voice)',
#   'credit_id': '52fe4284c3a36847f8024f9d',
#   'gender': 2,
#   'id': 7167,
#   'name': 'Don Rickles',
#   'order': 2,
#   'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'},
#  {'cast_id': 17,
#   'character': 'Slinky Dog (voice)',
#   'credit_id': '52fe4284c3a36847f8024fa1',
#   'gender': 2,
#   'id': 12899,
#   'name': 'Jim Varney',
#   'order': 3,
#   'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'},
#  {'cast_id': 18,
#   'character': 'Rex (voice)',
# ...

# %%
df.cast=df.cast.apply(lambda x:'|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
df.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44861              Leila Hatami|Kourosh Tahami|Elham Korda
# 44862    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44863    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44864    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44865
# Name: cast, Length: 44866, dtype: object

# %%
df.cast.value_counts().head(20)
# Out:
# cast
#                       2270
# Georges Méliès          24
# Louis Theroux           15
# Mel Blanc               12
# Jimmy Carr               9
# Werner Herzog            8
# Louis C.K.               8
# George Carlin            8
# David Attenborough       8
# Jim Jefferies            6
# Trevor Noah              6
# Ricky Gervais            6
# Doug Stanhope            6
# Patton Oswalt            6
# Bill Maher               5
# Jim Gaffigan             5
# Kenneth Branagh          5
# Lewis Black              5
# Dylan Moran              5
# Bill Burr                5
# Name: count, dtype: int64

# %%
df.cast.replace("", np.nan, inplace = True)

# %% [markdown]
# ## Cleaning and Transforming the new "Crew" Column

# %%
df.crew[0]
# Out:
# '[{\'credit_id\': \'52fe4284c3a36847f8024f49\', \'department\': \'Directing\', \'gender\': 2, \'id\': 7879, \'job\': \'Director\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f4f\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12891, \'job\': \'Screenplay\', \'name\': \'Joss Whedon\', \'profile_path\': \'/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f55\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7, \'job\': \'Screenplay\', \'name\': \'Andrew Stanton\', \'profile_path\': \'/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f5b\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12892, \'job\': \'Screenplay\', \'name\': \'Joel Cohen\', \'profile_path\': \'/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f61\', \'department\': \'Writing\', \'gender\': 0, \'id\': 12893, \'job\': \'Screenplay\', \'name\': \
# ...

# %%
df.crew = df.crew.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.crew[0]
# Out:
# [{'credit_id': '52fe4284c3a36847f8024f49',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 7879,
#   'job': 'Director',
#   'name': 'John Lasseter',
#   'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f4f',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12891,
#   'job': 'Screenplay',
#   'name': 'Joss Whedon',
#   'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f55',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 7,
#   'job': 'Screenplay',
#   'name': 'Andrew Stanton',
#   'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f5b',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12892,
#   'job': 'Screenplay',
#   'name': 'Joel Cohen',
#   'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f61',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 12893,
#   'job': 'Screenplay',
# ...

# %%
pd.DataFrame(df.crew[0])#detail information of the crew
# Out:
#                     credit_id  department  gender       id  \
# 0    52fe4284c3a36847f8024f49   Directing       2     7879
# 1    52fe4284c3a36847f8024f4f     Writing       2    12891
# 2    52fe4284c3a36847f8024f55     Writing       2        7
# 3    52fe4284c3a36847f8024f5b     Writing       2    12892
# 4    52fe4284c3a36847f8024f61     Writing       0    12893
# ..                        ...         ...     ...      ...
# 101  589216c19251412dc2009cb9       Sound       1  1748724
# 102  589216ccc3a3680973009274       Sound       0  1748725
# 103  589216d79251412dc8009aa0       Sound       0     8067
# 104  589216e49251412dcd009a4f  Production       1     7902
# 105  589216f39251412dc2009cf3  Production       0    84493
#
#                         job            name                      profile_path
# 0                  Director   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
# 1                Screenplay     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# ...

# %%
import numpy as np

def get_director(x):
    if isinstance(x, list):
        for i in x:
            if i['job'] == 'Director':
                return i['name']
    return np.nan

# Now apply this function to the 'crew' column
df["director"] = df.crew.apply(get_director)

# %%
df["director"] = df.crew.apply(get_director)

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44861    Hamid Nematollah
# 44862            Lav Diaz
# 44863      Mark L. Lester
# 44864    Yakov Protazanov
# 44865       Daisy Asquith
# Name: director, Length: 44866, dtype: object

# %%
df.head(2)
# Out:
#      id      title                                    tagline release_date  \
# 0   862  Toy Story                                        NaN   1995-10-30
# 1  8844    Jumanji  Roll the dice and unleash the excitement!   1995-12-15
#
#                      genres belongs_to_collection original_language  \
# 0   Animation|Comedy|Family  Toy Story Collection                en
# 1  Adventure|Fantasy|Family                   NaN                en
#
#    budget_musd  revenue_musd  \
# 0         30.0    373.554033
# 1         65.0    262.797249
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 0  United States of America      5415.0           7.7   21.946943     81.0
# 1  United States of America      2413.0           6.9   17.015539    104.0
#
# ...

# %%
df.drop(columns = ["crew"], inplace = True)

# %%
df.to_csv("movies_complete.csv", index = False)

# %% [markdown]
# *so far we import data, clean and merge it.Now we want to connect with database Sqlit*

# %% [markdown]
# ## Creating an SQLite Database and Connection

# %%
import sqlite3 as sq3

# %%
con = sq3.connect("movies.db")

# %%
con

# %%
con.execute("Select * FROM sqlite_master").fetchall()
# Out:
# [('table',
#   'movies_complete.csv',
#   'movies_complete.csv',
#   2,
#   'CREATE TABLE "movies_complete.csv" (\n"id" INTEGER,\n  "title" TEXT,\n  "tagline" TEXT,\n  "release_date" TEXT,\n  "genres" TEXT,\n  "belongs_to_collection" TEXT,\n  "original_language" TEXT,\n  "budget_musd" REAL,\n  "revenue_musd" REAL,\n  "production_companies" TEXT,\n  "production_countries" TEXT,\n  "vote_count" REAL,\n  "vote_average" REAL,\n  "popularity" REAL,\n  "runtime" REAL,\n  "overview" TEXT,\n  "spoken_languages" TEXT,\n  "poster_path" TEXT,\n  "cast" TEXT,\n  "director" TEXT\n)'),
#  ('table',
#   'votes.csv',
#   'votes.csv',
#   9628,
#   'CREATE TABLE "votes.csv" (\n"id" INTEGER,\n  "vote_count" REAL,\n  "vote_average" REAL\n)')]

# %%
con.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name").fetchall()
# Out:
# [('movies_complete.csv',), ('votes.csv',)]

# %% [markdown]
# ## Loading Data from DataFrames into an SQLite Database

# %%
 import sqlite3
import pandas as pd
# Load the CSV file into a DataFrame
df = pd.read_csv('movies_complete.csv')

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44866 entries, 0 to 44865
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44866 non-null  int64
#  1   title                  44866 non-null  object
#  2   tagline                20285 non-null  object
#  3   release_date           44821 non-null  object
#  4   genres                 42599 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44856 non-null  object
#  7   budget_musd            44866 non-null  float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33357 non-null  object
#  10  production_countries   38839 non-null  object
#  11  vote_count             44866 non-null  float64
#  12  vote_average           42138 non-null  float64
#  13  popularity             44866 non-null  float64
# ...

# %%
movies = df[["id", "title", "revenue_musd", "budget_musd", "belongs_to_collection", "release_date"]].copy()
movies
# Out:
#            id                        title  revenue_musd  budget_musd  \
# 0         862                    Toy Story    373.554033         30.0
# 1        8844                      Jumanji    262.797249         65.0
# 2       15602             Grumpier Old Men           NaN          0.0
# 3       31357            Waiting to Exhale     81.452156         16.0
# 4       11862  Father of the Bride Part II     76.578911          0.0
# ...       ...                          ...           ...          ...
# 44861  439050                       Subdue           NaN          0.0
# 44862  111109          Century of Birthing           NaN          0.0
# 44863   67758                     Betrayal           NaN          0.0
# 44864  227506             Satan Triumphant           NaN          0.0
# 44865  461257                     Queerama           NaN          0.0
#
#                 belongs_to_collection release_date
# 0                Toy Story Collection   1995-10-30
# ...

# %%
 movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44866 entries, 0 to 44865
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44866 non-null  int64
#  1   title                  44866 non-null  object
#  2   revenue_musd           7385 non-null   float64
#  3   budget_musd            44866 non-null  float64
#  4   belongs_to_collection  4463 non-null   object
#  5   release_date           44821 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
movies.release_date = pd.to_datetime(df.release_date)

# %%
# Write the DataFrame to the SQLite database
movies.to_sql('movies_complete.csv', con, if_exists='replace', index=False)
# Out:
# 44866

# %%
votes = df[["id", "vote_count", "vote_average"]].copy()
votes
# Out:
#            id  vote_count  vote_average
# 0         862      5415.0           7.7
# 1        8844      2413.0           6.9
# 2       15602        92.0           6.5
# 3       31357        34.0           6.1
# 4       11862       173.0           5.7
# ...       ...         ...           ...
# 44861  439050         1.0           4.0
# 44862  111109         3.0           9.0
# 44863   67758         6.0           3.8
# 44864  227506         0.0           NaN
# 44865  461257         0.0           NaN
#
# [44866 rows x 3 columns]

# %%
 votes.to_sql('votes.csv', con, if_exists='replace', index=False)
# Out:
# 44866

# %%
con.execute("Select * FROM sqlite_master").fetchall()
# Out:
# [('table',
#   'movies_complete.csv',
#   'movies_complete.csv',
#   2,
#   'CREATE TABLE "movies_complete.csv" (\n"id" INTEGER,\n  "title" TEXT,\n  "revenue_musd" REAL,\n  "budget_musd" REAL,\n  "belongs_to_collection" TEXT,\n  "release_date" TIMESTAMP\n)'),
#  ('table',
#   'votes.csv',
#   'votes.csv',
#   8901,
#   'CREATE TABLE "votes.csv" (\n"id" INTEGER,\n  "vote_count" REAL,\n  "vote_average" REAL\n)')]

# %%
con.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name").fetchall()
# Out:
# [('movies_complete.csv',), ('votes.csv',)]

# %%
# Close the connection
con.close()

# %% [markdown]
# ## Loading Data from SQLite Databases into DataFrames

# %%
import pandas as pd
import sqlite3 as sq3

# %%
con = sq3.connect("movies.db")

# %%
con.execute("Select * FROM sqlite_master").fetchall()
# Out:
# [('table',
#   'movies_complete.csv',
#   'movies_complete.csv',
#   2,
#   'CREATE TABLE "movies_complete.csv" (\n"id" INTEGER,\n  "title" TEXT,\n  "revenue_musd" REAL,\n  "budget_musd" REAL,\n  "belongs_to_collection" TEXT,\n  "release_date" TIMESTAMP\n)'),
#  ('table',
#   'votes.csv',
#   'votes.csv',
#   8901,
#   'CREATE TABLE "votes.csv" (\n"id" INTEGER,\n  "vote_count" REAL,\n  "vote_average" REAL\n)')]

# %%
import pandas as pd
from sqlalchemy import create_engine

# Create a connection to the SQLite database
engine = create_engine('sqlite:///movies.db')

# Read the table "movies_complete.csv" into a DataFrame
votes_data = pd.read_sql_table('votes.csv', con=engine)
movies_data = pd.read_sql_table('movies_complete.csv', con=engine)
# Close the connection
engine.dispose()

# Display the retrieved data
movies_data
# Out:
#            id                        title  revenue_musd  budget_musd  \
# 0         862                    Toy Story    373.554033         30.0
# 1        8844                      Jumanji    262.797249         65.0
# 2       15602             Grumpier Old Men           NaN          0.0
# 3       31357            Waiting to Exhale     81.452156         16.0
# 4       11862  Father of the Bride Part II     76.578911          0.0
# ...       ...                          ...           ...          ...
# 44861  439050                       Subdue           NaN          0.0
# 44862  111109          Century of Birthing           NaN          0.0
# 44863   67758                     Betrayal           NaN          0.0
# 44864  227506             Satan Triumphant           NaN          0.0
# 44865  461257                     Queerama           NaN          0.0
#
#                 belongs_to_collection release_date
# 0                Toy Story Collection   1995-10-30
# ...

# %%
votes_data
# Out:
#            id  vote_count  vote_average
# 0         862      5415.0           7.7
# 1        8844      2413.0           6.9
# 2       15602        92.0           6.5
# 3       31357        34.0           6.1
# 4       11862       173.0           5.7
# ...       ...         ...           ...
# 44861  439050         1.0           4.0
# 44862  111109         3.0           9.0
# 44863   67758         6.0           3.8
# 44864  227506         0.0           NaN
# 44865  461257         0.0           NaN
#
# [44866 rows x 3 columns]

# %% [markdown]
#  #   Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("movies_complete.csv", parse_dates= ["release_date"])

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %% [markdown]
# __Features__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]# name of actors in the movie id=1
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.describe()
# Out:
#              id                   release_date  budget_musd  revenue_musd  \
# count  44691.00                          44657      8854.00       7385.00
# mean  107186.24  1992-04-28 16:30:02.539355520        21.67         68.97
# min        2.00            1874-12-09 00:00:00         0.00          0.00
# 25%    26033.50            1978-08-12 00:00:00         2.00          2.41
# 50%    59110.00            2001-08-16 00:00:00         8.20         16.87
# 75%   154251.00            2010-12-10 00:00:00        25.00         67.64
# max   469172.00            2017-12-27 00:00:00       380.00       2787.97
# std   111806.36                            NaN        34.36        146.61
#
#        vote_count  vote_average  popularity  runtime  cast_size  crew_size
# count    44691.00      42077.00    44691.00 43179.00   44691.00   44691.00
# mean       111.65          6.00        2.96    97.57      12.48      10.31
# min          0.00          0.00        0.00     1.00       0.00       0.00
# ...

# %%
df.hist(figsize = (20, 12), bins = 100)# for numerical features
plt.show()

# %%
df.budget_musd.value_counts(dropna = False).head(20)
# Out:
# budget_musd
# NaN      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: count, dtype: int64

# %%
df.vote_average.value_counts(dropna = False)
# Out:
# vote_average
# NaN     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
#         ...
# 9.40       3
# 9.60       1
# 9.80       1
# 0.70       1
# 1.10       1
# Name: count, Length: 93, dtype: int64

# %%
df.vote_count.value_counts()
# Out:
# vote_count
# 1.00       3186
# 2.00       3056
# 3.00       2729
# 0.00       2614
# 4.00       2442
#            ...
# 2755.00       1
# 1187.00       1
# 4200.00       1
# 3322.00       1
# 2712.00       1
# Name: count, Length: 1820, dtype: int64

# %%
df.describe(include = "object")# for non numerical data
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %% [markdown]
# **here we can see that we have 44691 non missing values but 41605 of them  are unique so we inspect it for duplicate instanse**

# %%
df[df.title == "Cinderella"]
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# **but it seems that they are diffrent movies**

# %% [markdown]
# ## The best and the worst movies...

# %%
from IPython.display import HTML
pd.options.display.max_colwidth = 200

# %%
df_best = df[["poster_path", "title", "budget_musd", "revenue_musd",
              "vote_count", "vote_average", "popularity"]].copy()
df_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["return"] = df.revenue_musd.div(df.budget_musd)

# %%
df_best.head()
# Out:
#                                                                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          NaN           NaN       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# ...

# %%
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes", 
                   "Average Rating", "Popularity", "Profit", "ROI"]

# %%
df_best.set_index("Title", inplace = True)

# %%
df_best.head()
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
#
#                              Budget  Revenue   Votes  Average Rating  \
# Title
# Toy Story                     30.00   373.55 5415.00            7.70
# ...

# %%
df_best.iloc[0,0]# it includes html tag
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
subset = df_best.iloc[:5, :2]
subset
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
#
#                              Budget
# Title
# Toy Story                     30.00
# Jumanji                       65.00
# Grumpier Old Men                NaN
# Waiting to Exhale             16.00
# ...

# %% [markdown]
# **we can desplay these thml tags in our datafram**

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %%
df_best.sort_values(by = "Average Rating", ascending = False)
# Out:
#                                                                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2YxgYSJTcloGTHAA9ogOVq7M.jpg' style='height:100px;'>
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifPBA4AjRQWxgVJAwSwWp6nFCa.jpg' style='height:100px;'>
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOcmIjI8sx9RZIsVgOlq4kQgJ4.jpg' style='height:100px;'>
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH5tKdJa3y5jqAQM1eYmkXbHX.jpg' style='height:100px;'>
# ...

# %% [markdown]
# **this is not wery usfull approach because some rating is just based on 1 vote so we filter it**

# %%
df_best.sort_values(by = "ROI", ascending = False)
# Out:
#                                                                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'>
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'>
# Welcome to Dongmakgol     <img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'>
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflxxk94TjmjMdotXnajh64iMad.jpg' style='height:100px;'>
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne9mfUcL8QCGxF891LWa7lZNI.jpg' style='height:100px;'>
# ...                                                                                                                    ...
# ...

# %%
df_best.loc[df_best.Budget >= 5].sort_values(by = "ROI", ascending = False)
# Out:
#                                                                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'>
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'>
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'>
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xcqSFfT6F7ZXHxowjxfG0yisT.jpg' style='height:100px;'>
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwOZXU7ddSrWE3ryOQM8sIg1sZ.jpg' style='height:100px;'>
# ...

# %%
#we should not have missing values for filtering
df_best.Budget.fillna(0, inplace = True)
df_best.Votes.fillna(0, inplace = True)

# %%
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   44467 non-null  object
#  1   Budget          44691 non-null  float64
#  2   Revenue         7385 non-null   float64
#  3   Votes           44691 non-null  float64
#  4   Average Rating  42077 non-null  float64
#  5   Popularity      44691 non-null  float64
#  6   Profit          5371 non-null   float64
#  7   ROI             5371 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 3.1+ MB

# %%
def best_worst(n, by, ascending = False, min_bud = 0, min_votes = 0):
    
    
    df2 = df_best.loc[(df_best.Budget >= min_bud) & (df_best.Votes >= min_votes), 
                      ["", by]].sort_values(by = by, ascending = ascending).head(n).copy()
    
    return HTML(df2.to_html(escape=False))

# %% [markdown]
# **here we define function for best and worst movies and filter it by criteria and return it as HTML**

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst(n = 5, by = "Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(5, "Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
best_worst(5, "Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst(5, "Profit", ascending = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(5, "ROI", min_bud = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(5, "ROI", ascending = True, min_bud = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Live by Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bkd46T4RplawnDjpHoI8mhzTLks.jpg' style='height:100px;'></td>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(5, "Votes")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(5, "Average Rating", min_votes = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Planet Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//koVzjt54bJEVuKTmGC4cExcbE2w.jpg' style='height:100px;'></td>
#       <td>8.80</td>
#     </tr>
#     <tr>
#       <th>Sansho the Bailiff</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(5, "Average Rating", ascending = True, min_votes = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
# ...

# %%
best_worst(5, "Average Rating", ascending = True, min_votes = 20, min_bud = 20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>2.30</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst(5, "Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (high Rating)__

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
mask_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor = df.cast.str.contains("Bruce Willis")
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.loc[mask_actor & mask_genres, ["title", "vote_average"]].sort_values(by = "vote_average", 
                                                                        ascending = False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 27619                   Vice          4.10

# %%
bruce = df.loc[mask_actor & mask_genres, ["title", "poster_path", "vote_average"]].sort_values(by = "vote_average", ascending = False).set_index("title")

# %%
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Fifth Element</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>Looper</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>Armageddon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>Surrogates</th>
# ...

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (low runtime)__

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_director = df.director == "Quentin Tarantino"

# %%
mask_actor = df.cast.str.contains("Uma Thurman")

# %%
quentin = df.loc[mask_director & mask_actor, 
               ["title", "poster_path", "runtime"]].sort_values(by = "runtime").set_index("title")

# %%
HTML(quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (high Revenue)__

# %%
df.production_companies[1]
# Out:
# 'TriStar Pictures|Teitler Film|Interscope Communications'

# %%
mask_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 44686          NaT
# 44687   2011-11-17
# 44688   2003-08-01
# 44689   1917-10-21
# 44690   2017-06-09
# Name: release_date, Length: 44691, dtype: datetime64[ns]

# %%
mask_time = df.release_date.between("2010-01-01", "2015-12-31")

# %%
pixar = df.loc[mask_studio & mask_time, 
               ["title", "poster_path", "revenue_musd", "release_date"]].sort_values(by = "revenue_musd", ascending = False).set_index("title")

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent)__

# %%
mask_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")

# %%
mask_lan = df.original_language == "en"

# %%
mask_vote_av = df.vote_average >= 7.5

# %%
mask_vote_co = df.vote_count >= 10

# %%
next_mov = df.loc[mask_genre & mask_lan & mask_vote_av & mask_vote_co, 
               ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by = "release_date", ascending = False).set_index("title").head(20)

# %%
HTML(next_mov.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>7.50</td>
#       <td>2712.00</td>
# ...

# %% [markdown]
# ## Most Successful Directors

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
df.director.value_counts().head(20)
# Out:
# director
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Georges Méliès        49
# Woody Allen           49
# Jean-Luc Godard       46
# Sidney Lumet          46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Ingmar Bergman        39
# Martin Scorsese       39
# Fritz Lang            38
# John Huston           38
# George Cukor          38
# Mervyn LeRoy          37
# Robert Altman         37
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12, 8))
df.director.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Directors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
df.groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize = (12, 8))
df.groupby("director").revenue_musd.sum().nlargest(20).plot(kind='bar', fontsize = 15)
plt.title("Total Revenue",fontsize = 20)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.show()

# %%
directors = df.groupby("director").agg({"title": "count", "vote_average" :"mean", "vote_count": "sum"})

# %%
directors
# Out:
#                      title  vote_average  vote_count
# director
#  Dale Trevillion\t       2          4.00        4.00
#  Davide Manuli           1          6.90       10.00
#  E.W. Swackhamer         1          5.90        5.00
#  Vitaliy Vorobyov        1          5.50        3.00
#  Yeon Sang-Ho            4          6.60     1039.00
# ...                    ...           ...         ...
# Ярополк Лапшин           1         10.00        1.00
# پیمان معادی              1          6.00        2.00
# 塩谷 直義                    1          7.20       40.00
# 杰森·莫玛                    1          5.80       28.00
# 진모영                      1          6.00        6.00
#
# [17349 rows x 3 columns]

# %% [markdown]
# **directors with at least 10000 votes and 10 movies**

# %%
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, "vote_average")
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14          7.70    14700.00
# Christopher Nolan     11          7.62    67344.00
# Quentin Tarantino     10          7.49    45910.00
# Wes Anderson          10          7.37    11743.00
# David Fincher         10          7.35    37588.00
# Martin Scorsese       39          7.22    35541.00
# Peter Jackson         13          7.14    47571.00
# Joel Coen             17          7.02    18139.00
# James Cameron         11          6.93    33736.00
# Stanley Kubrick       16          6.91    18214.00
# James Mangold         10          6.90    16607.00
# Steven Spielberg      33          6.89    62266.00
# Danny Boyle           14          6.87    16504.00
# Guy Ritchie           10          6.80    19626.00
# Robert Zemeckis       19          6.79    37666.00
# Terry Gilliam         14          6.76    10049.00
# Tim Burton            21          6.73    36922.00
# ...

# %%
df.genres = df.genres.astype(str)

# %% [markdown]
# **the most successfull directors in  horror movies**

# %%
df.loc[df.genres.str.contains("Horror")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64

# %% [markdown]
# ## Most Successful Actors

# %%
df.cast
# Out:
# 0                                     Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyru...
# 2                                                                                                                 Walter Matthau|Jack Lemmon|Ann-Margret|Sophia Loren|Daryl Hannah|Burgess Meredith|Kevin Pollak
# 3                                                          Whitney Houston|Angela Bassett|Loretta Devine|Lela Rochon|Gregory Hines|Dennis Haysbert|Michael Beach|Mykelti Williamson|Lamont Johnson|Wesley Snipes
# ...

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                                               tagline  \
# 0                                                                                 NaN
# 1                                           Roll the dice and unleash the excitement!
# 2                                Still Yelling. Still Fighting. Still Ready for Love.
# 3      Friends are the people who let you be yourself... and never let you forget it.
# ...

# %% [markdown]
# **id is unique for each movies so we can use it as  index**

# %%
df.set_index("id", inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, 862 to 461257
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  44691 non-null  object
#  1   tagline                20284 non-null  object
#  2   release_date           44657 non-null  datetime64[ns]
#  3   genres                 44691 non-null  object
#  4   belongs_to_collection  4463 non-null   object
#  5   original_language      44681 non-null  object
#  6   budget_musd            8854 non-null   float64
#  7   revenue_musd           7385 non-null   float64
#  8   production_companies   33356 non-null  object
#  9   production_countries   38835 non-null  object
#  10  vote_count             44691 non-null  float64
#  11  vote_average           42077 non-null  float64
#  12  popularity             44691 non-null  float64
#  13  runtime                43179 non-null  float64
# ...

# %%
df.cast
# Out:
# id
# 862                                    Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyru...
# 15602                                                                                                              Walter Matthau|Jack Lemmon|Ann-Margret|Sophia Loren|Daryl Hannah|Burgess Meredith|Kevin Pollak
# 31357                                                       Whitney Houston|Angela Bassett|Loretta Devine|Lela Rochon|Gregory Hines|Dennis Haysbert|Michael Beach|Mykelti Williamson|Lamont Johnson|Wesley Snipes
# ...

# %%
df.cast.str.split("|", expand = True)
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
act = df.cast.str.split("|", expand = True)
act
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %% [markdown]
# **The stack() function in pandas pivots the columns of the DataFrame into the index, converting a wide format DataFrame to a long format DataFrame.**

# %%
act.stack().reset_index(level=1, drop=True).to_frame()
# Out:
#                         0
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act = act.stack().reset_index(level=1, drop=True).to_frame()

# %%
act
# Out:
#                         0
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act.columns = ["Actor"]

# %% [markdown]
# **merging with df to gain more information**

# %%
act = act.merge(df[["title", "revenue_musd", "vote_average", "popularity"]],
                how = "left", left_index = True, right_index = True)

# %%
act
# Out:
#                      Actor                            title  revenue_musd  \
# id
# 2              Turo Pajala                            Ariel           NaN
# 2         Susanna Haavisto                            Ariel           NaN
# 2          Matti Pellonpää                            Ariel           NaN
# 2             Eetu Hilkamo                            Ariel           NaN
# 3          Matti Pellonpää              Shadows in Paradise           NaN
# ...                    ...                              ...           ...
# 469172      Vasco Sequeira  Manuel on the Island of Wonders           NaN
# 469172     Armanda Bacelar  Manuel on the Island of Wonders           NaN
# 469172     Rafael de Sousa  Manuel on the Island of Wonders           NaN
# 469172  José Antônio Gomes  Manuel on the Island of Wonders           NaN
# 469172       Isabel Branco  Manuel on the Island of Wonders           NaN
#
#         vote_average  popularity
# id
# 2               7.10        3.86
# ...

# %%
act.Actor.value_counts().head(20)
# Out:
# Actor
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# Gérard Depardieu      109
# John Carradine        109
# Jackie Chan           108
# Donald Sutherland     108
# Frank Welker          107
# Robert De Niro        104
# Danny Trejo           101
# Steve Buscemi         101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Susan Sarandon         92
# Dennis Hopper          92
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12, 8))
act.Actor.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Actors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
agg = act.groupby("Actor").agg(Total_Revenue = ("revenue_musd", "sum"), 
                               Mean_Revenue = ("revenue_musd", "mean"),
                               Mean_Rating = ("vote_average", "mean"), 
                               Mean_Pop = ("popularity", "mean"), 
                               Total_Movies = ("Actor", "count"))

# %%
agg.nlargest(10, "Total_Movies")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Bess Flowers              368.91         14.76         6.18      2.03
# Christopher Lee          9417.05        324.73         5.91      4.75
# John Wayne                236.09         11.24         5.71      3.09
# Samuel L. Jackson       17109.62        213.87         6.27     11.70
# Michael Caine            8053.40        191.75         6.27      8.27
# Gérard Depardieu         1247.61         95.97         6.05      3.70
# John Carradine            255.84         19.68         5.55      2.43
# Donald Sutherland        5390.77        138.22         6.23      7.00
# Jackie Chan              4699.19        146.85         6.28      5.86
# Frank Welker            13044.15        326.10         6.31      9.57
#
#                    Total_Movies
# Actor
# Bess Flowers                240
# Christopher Lee             148
# John Wayne                  125
# Samuel L. Jackson           122
# ...

# %%
agg.nlargest(10, "Total_Revenue")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Stan Lee                19414.96        647.17         6.51     29.94
# Samuel L. Jackson       17109.62        213.87         6.27     11.70
# Warwick Davis           13256.03        662.80         6.29     13.09
# Frank Welker            13044.15        326.10         6.31      9.57
# John Ratzenberger       12596.13        449.86         6.48     10.96
# Jess Harnell            12234.61        611.73         6.44     10.92
# Hugo Weaving            11027.58        459.48         6.47     10.97
# Ian McKellen            11015.59        478.94         6.35     15.45
# Johnny Depp             10653.76        217.42         6.44     12.38
# Alan Rickman            10612.63        353.75         6.72     10.40
#
#                    Total_Movies
# Actor
# Stan Lee                     48
# Samuel L. Jackson           122
# Warwick Davis                34
# Frank Welker                107
# ...

# %%
plt.figure(figsize = (12, 8))
agg.Total_Revenue.nlargest(10).plot(kind='bar', fontsize = 15)
plt.title("Total Revenue",fontsize = 20)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.show()
